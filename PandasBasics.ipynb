# %%
# !pip install pandas

# %%
#import pandas
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
#1. Create Dataframe
df = pd.DataFrame([1,2,3])
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
df = pd.DataFrame([11,22,33],columns=['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Ram'],
    'Age': [16,17,18,19],
    'Salary' : [90000, 70000, 50000, 30000] 
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3       Ram   19   30000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#2. Basic Dataframe Understanding

# %%
df.head()   #top rowa
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3       Ram   19   30000

# %%
df.head(2)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000

# %%
df.tail()   #last rows
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3       Ram   19   30000

# %%
df.tail(2)
# Out:
#      Name  Age  Salary
# 2  Lalita   18   50000
# 3     Ram   19   30000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
#columns Rename
df.rename(columns={'Salary':'Monthly_Salary'})
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3       Ram   19           30000

# %%
df1=df.rename(columns={'Salary': 'Monthly_Salary'}, inplace=True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3       Ram   19           30000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
#3. Save and Load data from csv

# %%
#export dataframe
df.to_csv('Test_data.csv')

# %%
df.to_csv('Test_data.csv',index=False)

# %%
#import dataframe
load_df = pd.read_csv('Test_data.csv')
load_df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3       Ram   19           30000

# %%
#4. Rows & Column - Selection

# %%
#select column
#single column
df[['Name']]
# Out:
#        Name
# 0    Madhav
# 1  Vishakha
# 2    Lalita
# 3       Ram

# %%
df[['Name', 'Monthly_Salary']]
# Out:
#        Name  Monthly_Salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           50000
# 3       Ram           30000

# %%
# Select Rows
#loc- index name label based
#df.loc[df.Name=='Madhav']    #Square Brackets:
df.loc[(df.Name=='Madhav') & (df.Monthly_Salary>=50000)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
#iloc - index-value based
df.iloc[0:]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3       Ram   19           30000

# %%
df.iloc[0:2]   #[start:stop:step]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000

# %%
#5. Dataframe filter

# %%
df_age_filter = df[df['Age']>=17]

# %%
df_age_filter
# Out:
#        Name  Age  Monthly_Salary
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3       Ram   19           30000

# %%
df[(df['Age'] >= 18) & (df['Monthly_Salary'] >= 50000)]
# Out:
#      Name  Age  Monthly_Salary
# 2  Lalita   18           50000

# %%
df.where(df['Age'] >= 18)
# Out:
#      Name   Age  Monthly_Salary
# 0     NaN   NaN             NaN
# 1     NaN   NaN             NaN
# 2  Lalita  18.0         50000.0
# 3     Ram  19.0         30000.0

# %%
df.where(df['Age'] >= 18, other = 'Not Elegible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Elegible  Not Elegible   Not Elegible
# 1  Not Elegible  Not Elegible   Not Elegible
# 2        Lalita            18          50000
# 3           Ram            19          30000

# %%
#6. Rows and Columns - Operation (Add,Update,Delete)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3       Ram   19           30000

# %%
# Add New column
df['Team'] = ['CEO','HR','CTO','DA']
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3       Ram   19           30000   DA

# %%
df = df.drop_duplicates()
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3       Ram   19           30000   DA

# %%
df['Bonus'] = df['Monthly_Salary'] * 0.2
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3       Ram   19           30000   DA   6000.0

# %%
#ADD new rows
#df.loc[len(df)] = ['ABC', 21, 21000, 'IT',2000] 
df.loc[len(df)] = {
    'Name': 'ABC',
    'Age': 21,
    'Salary': 21000,
    'Team': 'IT',
    'Bonus': 2000
}
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16         90000.0  CEO  18000.0
# 1  Vishakha   17         70000.0   HR  14000.0
# 2    Lalita   18         50000.0  CTO  10000.0
# 3       Ram   19         30000.0   DA   6000.0
# 4       ABC   21             NaN   IT   2000.0

# %%
len(df)
# Out:
# 5

# %%
# Update Values
df.loc[0, 'Monthly_Salary'] = 95000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16         95000.0  CEO  18000.0
# 1  Vishakha   17         70000.0   HR  14000.0
# 2    Lalita   18         50000.0  CTO  10000.0
# 3       Ram   19         30000.0   DA   6000.0
# 4       ABC   21             NaN   IT   2000.0

# %%
# Update value - using column value
df.loc[df.Name == 'Madhav', 'Monthly_Salary'] = 90000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16         90000.0  CEO  18000.0
# 1  Vishakha   17         70000.0   HR  14000.0
# 2    Lalita   18         50000.0  CTO  10000.0
# 3       Ram   19         30000.0   DA   6000.0
# 4       ABC   21             NaN   IT   2000.0

# %%
# Delete Value - Rows and Columns Values

# %%
df.drop(df[df.Name == 'ABC'].index)   #drop row at axis=0
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16         90000.0  CEO  18000.0
# 1  Vishakha   17         70000.0   HR  14000.0
# 2    Lalita   18         50000.0  CTO  10000.0
# 3       Ram   19         30000.0   DA   6000.0

# %%
df.drop(5, axis=0)  #axis name

# %%
df.drop(7, axis=0)  #axis name

# %%
df[df.Name == 'ABC']

# %%
df.rename(columns={'Monthly_Salary':'Salary'},inplace=True)

# %%
# sort Values in Ascending order
df.sort_values('Salary')

# %%
#Descending order
df.sort_values('Salary', ascending= False)

# %%
#7. Working with Date values

# %%
#create new column
df['DOJ'] = [
    '2026-01-15',
    '2025-02-06',
    '2026-01-14',
    '2026-01-15',
    '2025-02-06'
]
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus         DOJ
# 0    Madhav   16         90000.0  CEO  18000.0  2026-01-15
# 1  Vishakha   17         70000.0   HR  14000.0  2025-02-06
# 2    Lalita   18         50000.0  CTO  10000.0  2026-01-14
# 3       Ram   19         30000.0   DA   6000.0  2026-01-15
# 4       ABC   21             NaN   IT   2000.0  2025-02-06

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
print(df)
print(df['DOJ'].dtype)
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ
# 0    Madhav   16         90000.0  CEO  18000.0 2026-01-15
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15
# 4       ABC   21             NaN   IT   2000.0 2025-02-06
# datetime64[ns]

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'],format = '%d-%m-%Y')

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ
# 0    Madhav   16         90000.0  CEO  18000.0 2026-01-15
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15
# 4       ABC   21             NaN   IT   2000.0 2025-02-06

# %%
print(df['DOJ'].dtype)
# Out:
# datetime64[ns]

# %%
#Extract Year, Month, Week, Day
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0     Thursday
# 1     Thursday
# 2    Wednesday
# 3     Thursday
# 4     Thursday
# Name: DOJ, dtype: object

# %%
df['Month'] = df['DOJ'].dt.month

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ  Month
# 0    Madhav   16         90000.0  CEO  18000.0 2026-01-15      1
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06      2
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14      1
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15      1
# 4       ABC   21             NaN   IT   2000.0 2025-02-06      2

# %%
df['DOJ'] + pd.Timedelta(days=90)
# Out:
# 0   2026-04-15
# 1   2025-05-07
# 2   2026-04-14
# 3   2026-04-15
# 4   2025-05-07
# Name: DOJ, dtype: datetime64[ns]

# %%
#8. Handling Missing Values

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ  Month
# 0    Madhav   16         90000.0  CEO  18000.0 2026-01-15      1
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06      2
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14      1
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15      1
# 4       ABC   21             NaN   IT   2000.0 2025-02-06      2

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team  Bonus    DOJ  Month
# 0  False  False           False  False  False  False  False
# 1  False  False           False  False  False  False  False
# 2  False  False           False  False  False  False  False
# 3  False  False           False  False  False  False  False
# 4  False  False            True  False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name=='Madhav', 'Monthly_Salary'] = np.nan

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ  Month  Salary
# 0    Madhav   16             NaN  CEO  18000.0 2026-01-15      1     NaN
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06      2     NaN
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14      1     NaN
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15      1     NaN
# 4       ABC   21             NaN   IT   2000.0 2025-02-06      2     NaN

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team  Bonus    DOJ  Month  Salary
# 0  False  False            True  False  False  False  False    True
# 1  False  False           False  False  False  False  False    True
# 2  False  False           False  False  False  False  False    True
# 3  False  False           False  False  False  False  False    True
# 4  False  False            True  False  False  False  False    True

# %%
df.isnull().sum()
# Out:
# Name              0
# Age               0
# Monthly_Salary    2
# Team              0
# Bonus             0
# DOJ               0
# Month             0
# Salary            5
# dtype: int64

# %%
df.fillna(50000)
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ  Month   Salary
# 0    Madhav   16         50000.0  CEO  18000.0 2026-01-15      1  50000.0
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06      2  50000.0
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14      1  50000.0
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15      1  50000.0
# 4       ABC   21         50000.0   IT   2000.0 2025-02-06      2  50000.0

# %%
#9. Aggregation and Group By

#To Know Total values (Frequency)

# %%
df['Team'].value_counts()
# Out:
# Team
# CEO    1
# HR     1
# CTO    1
# DA     1
# IT     1
# Name: count, dtype: int64

# %%
df['Month'].value_counts()
# Out:
# Month
# 1    3
# 2    2
# Name: count, dtype: int64

# %%
df[df['Month'] == 1]
# Out:
#      Name  Age  Monthly_Salary Team    Bonus        DOJ  Month  Salary
# 0  Madhav   16             NaN  CEO  18000.0 2026-01-15      1     NaN
# 2  Lalita   18         50000.0  CTO  10000.0 2026-01-14      1     NaN
# 3     Ram   19         30000.0   DA   6000.0 2026-01-15      1     NaN

# %%
df[df['Month'] == 1].shape[0]
# Out:
# 3

# %%
df.groupby('Month')['Monthly_Salary'].sum()  # Aggregation bassed on group by
# Out:
# Month
# 1    80000.0
# 2    70000.0
# Name: Monthly_Salary, dtype: float64

# %%
df.groupby('Month').agg({'Monthly_Salary' : 'mean', 'Name' : 'count'})
# Out:
#        Monthly_Salary  Name
# Month
# 1             40000.0     3
# 2             70000.0     2

# %%
#10. Concatenating and Merge Dataframe (JOINS)

# %%
df1 = pd.DataFrame({'ID':[1,2,3],'Name':['A','B','C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({'ID':[1,2,2,4],'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
#Verticle / Row-Level / Top on Top 
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
# Horizontal / Column Level / Side on Side
pd.concat([df1,df2], axis=1)
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %%
#Merge=Join

# %%
pd.merge(df1, df2, how='inner', on='ID')

'''pd.merge(df1, df2, how='left', on='ID')
pd.merge(df1, df2, how='right', on='ID')
pd.merge(df1, df2, how='outer', on='ID')'''
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1, df2, how='inner', left_on='ID', right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
#11. AI and ChatGPT

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus        DOJ  Month  Salary
# 0    Madhav   16             NaN  CEO  18000.0 2026-01-15      1     NaN
# 1  Vishakha   17         70000.0   HR  14000.0 2025-02-06      2     NaN
# 2    Lalita   18         50000.0  CTO  10000.0 2026-01-14      1     NaN
# 3       Ram   19         30000.0   DA   6000.0 2026-01-15      1     NaN
# 4       ABC   21             NaN   IT   2000.0 2025-02-06      2     NaN
