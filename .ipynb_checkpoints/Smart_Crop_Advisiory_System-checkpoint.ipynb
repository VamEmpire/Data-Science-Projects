# %%
# ---- Basic data handling------
import pandas as pd
import numpy as np

#---------Visulaization----------
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#-------Preprocessing------------
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#-------Classification models (Module 1)------
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

#----Clean up warning messages-----
import warnings
warnings.filterwarnings("ignore")

print("All Libraries Succeessfully! Ready to begin.")
# Out:
# All Libraries Succeessfully! Ready to begin.

# %% [markdown]
# # 🌾 Project Objectives
#
# In this project, we will **not** build just one Machine Learning model. Instead, we will develop a **Smart Crop Advisory System** consisting of **three interconnected Machine Learning modules**. Together, these modules answer the three most important questions a farmer needs before cultivation.
#
# | **Module** | **Question It Answers** | **Machine Learning Type** |
# |------------|--------------------------|----------------------------|
# | **Module 1: Crop Recommendation** | **Which crop is best suited to my soil and climate?** | **Classification** |
# | **Module 2: Crop Yield Prediction** | **How much production (yield) can I expect?** | **Regression** |
# | **Module 3: Profitability Analysis** | **Will growing this crop actually be profitable?** | **Regression + Ranking** |

# %% [markdown]
# # Module 1: Crop Recommendation System (Classification)

# %%
# Load the crop recommendation dataset directly from the internet
crop_reco_url = "https://raw.githubusercontent.com/AbhishekKandoi/Crop-Yield-Prediction-based-on-Indian-Agriculture/main/Crop%20Recommendation%20dataset.csv"

df_reco = pd.read_csv(crop_reco_url)
df_reco.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
print (f"Shape: {df_reco.shape}")
print()
print(f"Column names: {df_reco.columns.tolist()}")
print()
print("Missing values per Column:")
print(df_reco.isnull().sum())
# Out:
# Shape: (2200, 8)
#
# Column names: ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label']
#
# Missing values per Column:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# How many different crops (classes) are there, and how many sampless per crop?
df_reco['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
# Let's visualize the average nutrient requirement (N, P, K) for a few crops, to get a feel for the data
plt.figure(figsize=(10, 6))
sample_crops = ['mango', 'maize', 'cotton', 'coffee', 'apple','watermelon']
sns.barplot(x='label', y='N', data=df_reco[df_reco['label'].isin(sample_crops)], palette='viridis') 
plt.xlabel('Nitrogen (N)')
plt.ylabel('Phosphorus (P)')
plt.title('Nutrient Requirements for Different Crops')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create and apply a LabelEncoder for the crop names
crop_label_encoder = LabelEncoder()
df_reco['label'] = crop_label_encoder.fit_transform(df_reco['label']) 

# Let's see a few crop-to-number mappings
for i, crop_name in enumerate(crop_label_encoder.classes_[:5]):
    print(f"{crop_name}: -> {i}")
print("........and so on, for all", len(crop_label_encoder.classes_), "crops.")
# Out:
# apple: -> 0
# banana: -> 1
# blackgram: -> 2
# chickpea: -> 3
# coconut: -> 4
# ........and so on, for all 22 crops.

# %%
reco_features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall' ]

x_reco = df_reco[reco_features]
y_reco = df_reco['label']

# Split into 80% training, 20% testing
x_train_reco, x_test_reco, y_train_reco, y_test_reco = train_test_split(x_reco, y_reco, test_size=0.2, random_state=42)

print("Training data shape:", x_train_reco.shape[0])
print("Testing data shape:", x_test_reco.shape[0])
# Out:
# Training data shape: 1760
# Testing data shape: 440

# %%
# Create the two models
reco_models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42)
}

# Train (fit) each momdel using the training data
#.items()- returns both key and value

reco_trained_models = {}
for name, model in reco_models.items():
    trained_model = model.fit(x_train_reco, y_train_reco)
    reco_trained_models[name] = trained_model
    print(f"{name} model trained Successfuly.")
# Out:
# Decision Tree model trained Successfuly.
# Random Forest model trained Successfuly.

# %%
for name, model in reco_trained_models.items():
    y_pred_reco = model.predict(x_test_reco)
    accuracy = accuracy_score(y_test_reco, y_pred_reco)
    print(f"{name} Accuracy: {accuracy * 100:.2f}%")
# Out:
# Decision Tree Accuracy: 98.64%
# Random Forest Accuracy: 99.32%

# %%
# Let's look closer at the the Random Forest model using
best_reco_model = reco_trained_models['Random Forest']
y_pred_reco = best_reco_model.predict(x_test_reco)

print(classification_report(y_test_reco, y_pred_reco, target_names=crop_label_encoder.classes_))
#
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       1.00      1.00      1.00        17
#       cotton       1.00      1.00      1.00        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.92      1.00      0.96        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.92      1.00      0.96        11
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.96      0.98        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
# ...

# %%
reco_importance = pd.DataFrame({'Feature': reco_features, 'Importance': best_reco_model.feature_importances_}).sort_values('Importance', ascending=False)
plt.figure(figsize=(7,4))
print(reco_importance)
print()

sns.barplot(x='Feature', y='Importance', data=reco_importance, palette='viridis')
plt.xlabel('Importance')
plt.title('Feature Importance in Crop Recommendation')
plt.show()
# Out:
#        Feature  Importance
# 6     rainfall    0.227036
# 4     humidity    0.211279
# 2            K    0.181222
# 1            P    0.143622
# 0            N    0.108859
# 3  temperature    0.075682
# 5           ph    0.052301

# %%
def recommend_crop(N, P, K, temperature, humidity, ph, rainfall):
  """
  Given soil nutrient and climate values, returns the recommended crop name.
  """
  # Put the inputs into a  DataFrame with the samae column names/order used during training
  input_data = pd.DataFrame([[N, P, K, temperature, humidity, ph, rainfall]], columns=reco_features)

  # Predict the encoded crop number
  predicted_crop = best_reco_model.predict(input_data)[0]

  # Convert the number back into a crop name
  predicted_crop = crop_label_encoder.inverse_transform([predicted_crop])[0]

  return predicted_crop 
# Let's test our function with a sample input
sample_prediction = recommend_crop(N=90, P=40, K=40, temperature=20.879744, humidity=82.002744, ph=6.502985, rainfall=202.935536)
print(f"Recommended Crop: {sample_prediction}")
# Out:
# Recommended Crop: rice

# %% [markdown]
# # MODULE 2: CROP YIELD PREDICTION (REGRESSION)

# %%
# Load the Indian crop production dataset from the Internet
crop_yield_url = "https://raw.githubusercontent.com/AbhishekKandoi/Crop-Yield-Prediction-based-on-Indian-Agriculture/main/Crop%20Prediction%20dataset.csv"

df_yield = pd.read_csv(crop_yield_url)
df_yield.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop  Temperature  Humidity  Soil_Moisture    Area  \
# 0             Arecanut           36        35             45  1254.0
# 1  Other Kharif pulses           37        40             46     2.0
# 2                 Rice           36        41             50   102.0
# 3               Banana           37        42             55   176.0
# 4            Cashewnut           36        40             54   720.0
#
#    Production
# 0      2000.0
# 1         1.0
# 2       321.0
# 3       641.0
# 4       165.0

# %%
print (f"Shape: {df_yield.shape}")
print()
print(f"Column names: {df_yield.columns.tolist()}")
print()
print("Missing values per Column:")
print(df_yield.isnull().sum())
# Out:
# Shape: (49675, 11)
#
# Column names: ['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Temperature', 'Humidity', 'Soil_Moisture', 'Area', 'Production', 'Yield']
#
# Missing values per Column:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Temperature      0
# Humidity         0
# Soil_Moisture    0
# Area             0
# Production       0
# Yield            0
# dtype: int64

# %%
df_yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49675 entries, 0 to 49998
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     49675 non-null  object
#  1   District_Name  49675 non-null  object
#  2   Crop_Year      49675 non-null  int64
#  3   Season         49675 non-null  object
#  4   Crop           49675 non-null  object
#  5   Temperature    49675 non-null  int64
#  6   Humidity       49675 non-null  int64
#  7   Soil_Moisture  49675 non-null  int64
#  8   Area           49675 non-null  float64
#  9   Production     49675 non-null  float64
#  10  Yield          49675 non-null  float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 4.5+ MB

# %%
# Let's inspect the unique values in the Season column - watch closely for extra
df_yield['Season'].unique()
# Out:
# array(['Kharif', 'Whole Year', 'Autumn', 'Rabi', 'Summer', 'Winter'],
#       dtype=object)

# %%
# 1. Remove extra spaces from
df_yield['Season'] = df_yield['Season'].str.strip()
df_yield['Crop'] = df_yield['Crop'].str.strip()
df_yield['State_Name'] = df_yield['State_Name'].str.strip()
df_yield['District_Name'] = df_yield['District_Name'].str.strip()

 #2. Remove rows where Production is missing
df_yield = df_yield.dropna(subset=['Production'])

 #3. Remove rows where Production or Area is zero (these rows are not useful)
df_yield = df_yield[(df_yield['Production'] != 0) & (df_yield['Area'] != 0)]

 #4. Create the yield column
df_yield['Yield'] = df_yield['Production'] / df_yield['Area']

print("Shape after cleaning:", df_yield.shape)
df_yield[['Yield', 'Production', 'Area']].head()
# Out:
# Shape after cleaning: (49675, 11)
#       Yield  Production    Area
# 0  1.594896      2000.0  1254.0
# 1  0.500000         1.0     2.0
# 2  3.147059       321.0   102.0
# 3  3.642045       641.0   176.0
# 4  0.229167       165.0   720.0

# %%
# Let's look at the spread of our new aYiels column before removing outliers
df_yield['Yield'].describe()
# Out:
# count    49675.000000
# mean        84.418067
# std        930.718123
# min          0.000505
# 25%          0.619400
# 50%          1.055944
# 75%          2.892503
# max      33089.005477
# Name: Yield, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_yield['Yield'], bins=30, kde=True)
plt.title('Distribution of Crop Yields')
plt.xlabel('Yield')
plt.ylabel('Frequency')
plt.show()

# %%
#5. Keep only rows below the 95th ercentile of yield, to remove 
yield_cutoff = df_yield['Yield'].quantile(0.95)
print("95th percentile Yield cutoff:", round(yield_cutoff, 2))

df_yield = df_yield[df_yield['Yield'] <= yield_cutoff]

print("Shape after removing outliers:", df_yield.shape)
# Out:
# 95th percentile Yield cutoff: 18.75
# Shape after removing outliers: (47192, 11)

# %%
# Let's Visualize the Yied distribution now - it should look
plt.figure(figsize=(10, 6))
sns.histplot(df_yield['Yield'], bins=30, kde=True)
plt.title('Distribution of Crop Yields')
plt.ylabel('Distribution of crop yield(after cleaning)')
plt.xlabel('Yield (production per unit Area)')
plt.show()

# %%
yield_categorical_cols = ['State_Name', 'District_Name', 'Season', 'Crop']
yield_numerical_cols = ['Area', 'Production']

# Create one LabelEncoder per categorical column, and remember them in a dictionary
yield_encoder = {}

for col in yield_categorical_cols:
  le = LabelEncoder()
  df_yield[col + '_Encoded'] = le.fit_transform(df_yield[col])
  yield_encoder[col] = le

df_yield[['State_Name', 'District_Name', 'Season', 'Crop', 'State_Name_Encoded', 'District_Name_Encoded', 'Season_Encoded', 'Crop_Encoded']].head()
# Out:
#                     State_Name District_Name      Season                 Crop  \
# 0  Andaman and Nicobar Islands      NICOBARS      Kharif             Arecanut
# 1  Andaman and Nicobar Islands      NICOBARS      Kharif  Other Kharif pulses
# 2  Andaman and Nicobar Islands      NICOBARS      Kharif                 Rice
# 3  Andaman and Nicobar Islands      NICOBARS  Whole Year               Banana
# 4  Andaman and Nicobar Islands      NICOBARS  Whole Year            Cashewnut
#
#    State_Name_Encoded  District_Name_Encoded  Season_Encoded  Crop_Encoded
# 0                   0                     78               1             0
# 1                   0                     78               1            44
# 2                   0                     78               1            55
# 3                   0                     78               4             3
# 4                   0                     78               4            11
